# %% [markdown]
# K-means封装

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# %%
class KMeans:
    def __init__(self, n_clusters=3,max_iters=100):
        #初始化KMeans
        self.n_clusters = n_clusters 
        self.max_iters = max_iters
        #集簇质心
        self.centroids = None

     def fit(self,x):
         np.random.seed(0) 
         #1.随机选择k个数据点作为初始的质心
         ramdom_indices = np.ramdom.choice(len(x), self.n_clusters, replace=False) 
         self.centorids = x[random_indices]
         
         #计算平均距离，更新质心
         for _ in range(self.max_iters):
             #2.通过下面定义的_assign_clusters计算每个点到质心的距离找到最近的质心
             labels = self._assign_clusters(x) 
             #3.根据每个簇的平均值计算新质心
              new_centroids = np.array([x[labels == k].mean(axis=0) for k in range(self.n_clusters)])
             #4.质心不再变化则结束
             if np.all(new_centroids == self.centroids):
                break
            #更新质心
            self.centroids = new_centroids 

        def _assign_clusters(self, x):
            distances = np.linalg.norm(x[:, np.newaxis] - self.centroids, axis=2)  
            return np.argmin(distances, axis=1)

        def predict(self, x):
             return self._assign_clusters(X)

# %% [markdown]
# 加载鸢尾花iris数据

# %%
from sklearn.datasets import load_iris
#加载iris数据集
iris = load_iris()
#我暂时只取了前两个特征（花萼长度和花萼宽度）
x = iris.data[:, :2] 

#调用KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(x)
labels = kmeans.predict(x)

#图像
plt.scatter(x[:, 0], x[:, 1], c=labels, cmap='viridis', alpha=0.7)
plt.scatter(kmeans.centroids[:, 0], kmeans.centroids[:, 1], 
            c='red', marker='x', s=200, label='Centroids')  # 质心
plt.title("kmeans-iris")
plt.xlabel("Sepal Length ")
plt.ylabel("Sepal Width ")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from sklearn.datasets import load_iris
#       2 #加载iris数据集
#       3 iris = load_iris()
#
# ModuleNotFoundError: No module named 'sklearn'
